# %% [markdown]
# # Result View
#
# Use this notebook to read saved metrics and view figures.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
basic_results = PROJECT_ROOT / 'results' / 'metrics' / 'basic_results.csv'

if basic_results.exists():
    display(pd.read_csv(basic_results))
else:
    print('Run training first.')
