# %% [markdown]
# # Chương 4 — Hình đánh giá Hybrid CNN–BiLSTM và Recommendation V
#
# Notebook này **chỉ vẽ số đã khóa**. Không train lại, không bịa epoch. Chạy cả file để ghi 18 PNG vào `figures/`.
#
# Nguồn: `uci_final.csv`, `oulad_final.csv`, `OVERFIT_AUDIT.json`, OOF 66 685 dòng, Panel C 632 case, baseline tensor-parity.

# %%
from pathlib import Path
from IPython.display import Image, display, Markdown
import generate_ch4_figures as g

paths = g.main()
print(len(paths), "figures")
for p in paths:
    display(Markdown(f"**{p.name}**"))
    display(Image(filename=str(p), width=720))
